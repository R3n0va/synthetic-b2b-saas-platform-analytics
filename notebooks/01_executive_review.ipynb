# %% [markdown]
# # Executive SaaS review
#
# Run from the repository root after generating `data/sample` and `reports/sample`.

# %%
from pathlib import Path
import json
import pandas as pd
ROOT = Path.cwd()
summary = json.loads((ROOT / 'reports/sample/executive_summary.json').read_text())
summary

# %%
bridge = pd.read_csv(ROOT / 'reports/sample/mrr_bridge.csv')
bridge.tail(12)

# %%
country = pd.read_csv(ROOT / 'reports/sample/country_performance.csv')
country.sort_values('mrr_eur', ascending=False).head(10)
