# %% [markdown]
# # Revenue and retention review
#
# Run from the repository root after generating `data/sample` and `reports/sample`.

# %%
from pathlib import Path
import pandas as pd
ROOT = Path.cwd()
movements = pd.read_csv(ROOT / 'reports/sample/account_mrr_movements.csv')
retention = pd.read_csv(ROOT / 'reports/sample/revenue_retention.csv')

# %%
movements.groupby('movement_type', dropna=False)['movement_mrr'].sum().sort_values()

# %%
retention.tail(12)
