# %% [markdown]
# # Experiment decision review
#
# Run from the repository root after generating `data/sample` and `reports/sample`.

# %%
from pathlib import Path
import pandas as pd
ROOT = Path.cwd()
experiments = pd.read_csv(ROOT / 'reports/sample/experiment_decisions.csv')
experiments

# %%
experiments[['experiment_name','absolute_effect','ci_lower','ci_upper','p_value','decision']]
